# %%
from statsbombpy import sb
import pandas as pd
from mplsoccer import Pitch, Sbopen
import matplotlib.pyplot as plt
comps = sb.competitions()
# comps["competition_name"].unique()
comps[comps["competition_name"]=="FIFA World Cup"]
# Out:
#     competition_id  season_id   country_name competition_name  \
# 29              43        106  International   FIFA World Cup
# 30              43          3  International   FIFA World Cup
# 31              43         55  International   FIFA World Cup
# 32              43         54  International   FIFA World Cup
# 33              43         51  International   FIFA World Cup
# 34              43        272  International   FIFA World Cup
# 35              43        270  International   FIFA World Cup
# 36              43        269  International   FIFA World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 29               male              False                       True
# 30               male              False                       True
# 31               male              False                       True
# 32               male              False                       True
# 33               male              False                       True
# 34               male              False                       True
# 35               male              False                       True
# 36               male              False                       True
#
#    season_name               match_updated           match_updated_360  \
# 29        2022  2024-12-16T10:15:11.055845  2024-12-16T10:21:13.710934
# 30        2018  2024-06-12T07:38:19.345758     2021-06-13T16:17:31.694
# 31        1990  2023-06-28T10:58:20.137929     2021-06-12T16:17:31.694
# 32        1986  2023-12-26T22:34:04.263530     2021-06-13T16:17:31.694
# 33        1974  2024-02-13T02:52:29.582599     2021-06-13T16:17:31.694
# 34        1970  2024-02-13T14:23:06.735299                        None
# 35        1962  2023-06-26T10:38:00.323984                        None
# 36        1958  2024-02-13T14:22:08.222297                        None
#
#            match_available_360             match_available
# 29  2024-12-16T10:21:13.710934  2024-12-16T10:15:11.055845
# 30                        None  2024-06-12T07:38:19.345758
# 31                        None  2023-06-28T10:58:20.137929
# 32                        None  2023-12-26T22:34:04.263530
# 33                        None  2024-02-13T02:52:29.582599
# 34                        None  2024-02-13T14:23:06.735299
# 35                        None  2023-06-26T10:38:00.323984
# 36                        None  2024-02-13T14:22:08.222297

# %%
matches=sb.matches(competition_id=43,season_id=106)
matches[matches['home_team']=='Belgium']
# Out:
#     match_id  match_date      kick_off  home_score  away_score match_status  \
# 32   3857283  2022-11-27  15:00:00.000           0           2    available
# 58   3857268  2022-11-23  21:00:00.000           1           0    available
#
#    match_status_360                last_updated            last_updated_360  \
# 32        available  2023-02-28T21:26:37.636261  2023-06-21T18:29:02.259940
# 58        available  2023-08-12T16:44:27.619465  2023-08-12T16:48:09.197442
#
#     match_week  ...  home_manager_country_name away_manager_id  \
# 32           2  ...                      Spain         1000518
# 58           1  ...                      Spain            4435
#
#    away_manager_name away_manager_nickname  away_manager_dob  \
# 32    Walid Regragui                  None        1975-09-23
# 58      John Herdman                  None        1975-07-19
#
#    away_manager_country_id  away_manager_country_name data_version  \
# 32                     154                    Morocco        1.1.0
# 58                      68                    England        1.1.0
#
#    shot_fidelity_version xy_fidelity_version
# 32                     2                   2
# 58                     2                   2
#
# [2 rows x 55 columns]

# %%
events = sb.events(match_id=3857283)
parser = Sbopen()
df, related, freeze, tactics = parser.event(3857283)
df.columns
# Out:
# Index(['id', 'index', 'period', 'timestamp', 'minute', 'second', 'possession',
#        'duration', 'match_id', 'type_id', 'type_name', 'possession_team_id',
#        'possession_team_name', 'play_pattern_id', 'play_pattern_name',
#        'team_id', 'team_name', 'tactics_formation', 'player_id', 'player_name',
#        'position_id', 'position_name', 'pass_recipient_id',
#        'pass_recipient_name', 'pass_length', 'pass_angle', 'pass_height_id',
#        'pass_height_name', 'end_x', 'end_y', 'body_part_id', 'body_part_name',
#        'sub_type_id', 'sub_type_name', 'x', 'y', 'under_pressure',
#        'outcome_id', 'outcome_name', 'ball_recovery_recovery_failure',
#        'counterpress', 'pass_cross', 'off_camera', 'out',
#        'pass_assisted_shot_id', 'pass_shot_assist', 'shot_statsbomb_xg',
#        'end_z', 'shot_key_pass_id', 'technique_id', 'technique_name',
#        'shot_first_time', 'goalkeeper_position_id', 'goalkeeper_position_name',
#        'pass_switch', 'aerial_won', 'dribble_overrun',
#        'ball_recovery_offensive', 'dribble_nutmeg', 'block_deflection',
#        'foul_committed_card_id', 'foul_committed_card_name',
#        'foul_won_defensive', 'pass_miscommunication',
#        'foul_committed_offensive', 'substitution_replacement_id',
#        'substitution_replacement_name', 'pass_deflected', 'block_offensive',
#        'pass_goal_assist', 'shot_one_on_one', 'shot_open_goal',
#        'pass_no_touch', 'foul_committed_advantage', 'foul_won_advantage',
#        'pass_cut_back'],
#       dtype='object')

# %%
df = df[df['team_name']=="Belgium"]
df['type_name'].unique()
# Out:
# array(['Starting XI', 'Half Start', 'Pass', 'Ball Receipt', 'Carry',
#        'Ball Recovery', 'Dispossessed', 'Pressure', 'Dribbled Past',
#        'Foul Won', 'Dribble', 'Miscontrol', 'Injury Stoppage',
#        'Clearance', 'Duel', 'Shot', 'Shield', 'Block', '50/50',
#        'Foul Committed', 'Interception', 'Goal Keeper', 'Offside',
#        'Half End', 'Substitution', 'Tactical Shift'], dtype=object)

# %%
passes = df[df['type_name']=='Pass']
passes.columns
# Out:
# Index(['id', 'index', 'period', 'timestamp', 'minute', 'second', 'possession',
#        'duration', 'match_id', 'type_id', 'type_name', 'possession_team_id',
#        'possession_team_name', 'play_pattern_id', 'play_pattern_name',
#        'team_id', 'team_name', 'tactics_formation', 'player_id', 'player_name',
#        'position_id', 'position_name', 'pass_recipient_id',
#        'pass_recipient_name', 'pass_length', 'pass_angle', 'pass_height_id',
#        'pass_height_name', 'end_x', 'end_y', 'body_part_id', 'body_part_name',
#        'sub_type_id', 'sub_type_name', 'x', 'y', 'under_pressure',
#        'outcome_id', 'outcome_name', 'ball_recovery_recovery_failure',
#        'counterpress', 'pass_cross', 'off_camera', 'out',
#        'pass_assisted_shot_id', 'pass_shot_assist', 'shot_statsbomb_xg',
#        'end_z', 'shot_key_pass_id', 'technique_id', 'technique_name',
#        'shot_first_time', 'goalkeeper_position_id', 'goalkeeper_position_name',
#        'pass_switch', 'aerial_won', 'dribble_overrun',
#        'ball_recovery_offensive', 'dribble_nutmeg', 'block_deflection',
#        'foul_committed_card_id', 'foul_committed_card_name',
#        'foul_won_defensive', 'pass_miscommunication',
#        'foul_committed_offensive', 'substitution_replacement_id',
#        'substitution_replacement_name', 'pass_deflected', 'block_offensive',
#        'pass_goal_assist', 'shot_one_on_one', 'shot_open_goal',
#        'pass_no_touch', 'foul_committed_advantage', 'foul_won_advantage',
#        'pass_cut_back'],
#       dtype='object')

# %%
passes = passes[['id','minute','player_id','player_name','x','y','end_x', 'end_y','pass_recipient_id','pass_recipient_name','outcome_id','outcome_name']]

# %%
successful=passes[passes['outcome_name'].isnull()]

# %%
successful
# Out:
#                                         id  minute  player_id  \
# 4     f8d0bd4d-b769-44b6-9114-9a4fae7ee547       0     3457.0
# 7     8eced6a4-ea03-4e03-b90f-ff09ff38996f       0     5642.0
# 10    3c96e345-701d-4260-b2a5-6203f1cceceb       0    20005.0
# 13    4228680a-ce97-49c0-8cfd-a13fbd7c0068       0    48347.0
# 16    1f2153bb-0cdb-4ae1-8f1c-df5774b28086       0    20005.0
# ...                                    ...     ...        ...
# 3574  3e3150d4-53a3-4b4b-a29d-594fd53aacb6      93     3077.0
# 3577  b3c97635-384d-4517-926a-46bfeba1658c      93    20005.0
# 3595  a350d989-6f1e-47d5-961c-2ccaecc8f355      94     3509.0
# 3611  4a319215-fdb9-4a51-947b-719813a19a96      94     5642.0
# 3617  5a830808-27dd-41b7-9df8-8a6a569ba4a7      95     5642.0
#
#                 player_name     x     y  end_x  end_y  pass_recipient_id  \
# 4     Michy Batshuayi Tunga  60.0  40.0   52.9   36.0             5642.0
# 7               Axel Witsel  49.9  37.1   32.6   54.2            20005.0
# 10        Toby Alderweireld  32.6  54.2   43.4   52.2            48347.0
# 13             Amadou Onana  43.4  52.2   30.7   56.2            20005.0
# 16        Toby Alderweireld  30.7  56.2   22.8   28.2             3077.0
# ...                     ...   ...   ...    ...    ...                ...
# 3574         Jan Vertonghen  56.7  19.2   56.7   48.1            20005.0
# 3577      Toby Alderweireld  56.9  47.9   66.6   63.3             3089.0
# 3595       Thibaut Courtois  15.2  37.0   29.6   34.8             5642.0
# 3611            Axel Witsel  19.7   9.6   27.2   10.0             3077.0
# 3617            Axel Witsel  31.3  10.9   45.0   31.4             2954.0
#
#      pass_recipient_name  outcome_id outcome_name
# 4            Axel Witsel         NaN          NaN
# 7      Toby Alderweireld         NaN          NaN
# 10          Amadou Onana         NaN          NaN
# 13     Toby Alderweireld         NaN          NaN
# 16        Jan Vertonghen         NaN          NaN
# ...                  ...         ...          ...
# 3574   Toby Alderweireld         NaN          NaN
# 3577     Kevin De Bruyne         NaN          NaN
# 3595         Axel Witsel         NaN          NaN
# 3611      Jan Vertonghen         NaN          NaN
# 3617     Youri Tielemans         NaN          NaN
#
# [604 rows x 12 columns]

# %%
df_lineup = parser.lineup(3857283)
jersey_data=df_lineup[['player_id','jersey_number']]
jersey_data
# Out:
#     player_id  jersey_number
# 0        2954              8
# 1        3077              5
# 2        3089              7
# 3        3176             15
# 4        3289              9
# 5        3457             23
# 6        3509              1
# 7        3539             12
# 8        3621             10
# 9        5630             14
# 10       5632             16
# 11       5633             11
# 12       5642              6
# 13       6331             19
# 14       6989             21
# 15       8240             13
# 16       8854              4
# 17      16275             24
# 18      16281             20
# 19      16559             17
# 20      20005              2
# 21      23650             25
# 22      32688             22
# 23      43913              3
# 24      48347             18
# 25     114832             26
# 26       3625             17
# 27       3634             11
# 28       5219              6
# 29       5233             12
# 30       5234              4
# 31       5237              7
# 32       5245              2
# 33       6301             19
# 34       6785              1
# 35       7459             18
# 36      12149              5
# 37      15890              3
# 38      21214             13
# 39      21736             14
# 40      23774             15
# 41      31295             25
# 42      46258              8
# 43      59493              9
# 44      67700             24
# 45     102668             26
# 46     131037             10
# 47     139011             22
# 48     139016             20
# 49     149714             16
# 50     156734             23
# 51     296254             21

# %%
successful= pd.merge(successful,jersey_data,on='player_id')
successful.rename(columns={'jersey_number':'passer'},inplace=True)
successful
# Out:
#                                        id  minute  player_id  \
# 0    f8d0bd4d-b769-44b6-9114-9a4fae7ee547       0     3457.0
# 1    8eced6a4-ea03-4e03-b90f-ff09ff38996f       0     5642.0
# 2    3c96e345-701d-4260-b2a5-6203f1cceceb       0    20005.0
# 3    4228680a-ce97-49c0-8cfd-a13fbd7c0068       0    48347.0
# 4    1f2153bb-0cdb-4ae1-8f1c-df5774b28086       0    20005.0
# ..                                    ...     ...        ...
# 599  3e3150d4-53a3-4b4b-a29d-594fd53aacb6      93     3077.0
# 600  b3c97635-384d-4517-926a-46bfeba1658c      93    20005.0
# 601  a350d989-6f1e-47d5-961c-2ccaecc8f355      94     3509.0
# 602  4a319215-fdb9-4a51-947b-719813a19a96      94     5642.0
# 603  5a830808-27dd-41b7-9df8-8a6a569ba4a7      95     5642.0
#
#                player_name     x     y  end_x  end_y  pass_recipient_id  \
# 0    Michy Batshuayi Tunga  60.0  40.0   52.9   36.0             5642.0
# 1              Axel Witsel  49.9  37.1   32.6   54.2            20005.0
# 2        Toby Alderweireld  32.6  54.2   43.4   52.2            48347.0
# 3             Amadou Onana  43.4  52.2   30.7   56.2            20005.0
# 4        Toby Alderweireld  30.7  56.2   22.8   28.2             3077.0
# ..                     ...   ...   ...    ...    ...                ...
# 599         Jan Vertonghen  56.7  19.2   56.7   48.1            20005.0
# 600      Toby Alderweireld  56.9  47.9   66.6   63.3             3089.0
# 601       Thibaut Courtois  15.2  37.0   29.6   34.8             5642.0
# 602            Axel Witsel  19.7   9.6   27.2   10.0             3077.0
# 603            Axel Witsel  31.3  10.9   45.0   31.4             2954.0
#
#     pass_recipient_name  outcome_id outcome_name  passer
# 0           Axel Witsel         NaN          NaN      23
# 1     Toby Alderweireld         NaN          NaN       6
# 2          Amadou Onana         NaN          NaN       2
# 3     Toby Alderweireld         NaN          NaN      18
# 4        Jan Vertonghen         NaN          NaN       2
# ..                  ...         ...          ...     ...
# 599   Toby Alderweireld         NaN          NaN       5
# 600     Kevin De Bruyne         NaN          NaN       2
# 601         Axel Witsel         NaN          NaN       1
# 602      Jan Vertonghen         NaN          NaN       6
# 603     Youri Tielemans         NaN          NaN       6
#
# [604 rows x 13 columns]

# %%
jersey_data.rename(columns={'player_id':'pass_recipient_id'},inplace=True)
successful = pd.merge(successful,jersey_data, on='pass_recipient_id')
successful.rename(columns={'jersey_number':'recipient'},inplace=True)
successful
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12692\1718113474.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jersey_data.rename(columns={'player_id':'pass_recipient_id'},inplace=True)
#                                        id  minute  player_id  \
# 0    f8d0bd4d-b769-44b6-9114-9a4fae7ee547       0     3457.0
# 1    8eced6a4-ea03-4e03-b90f-ff09ff38996f       0     5642.0
# 2    3c96e345-701d-4260-b2a5-6203f1cceceb       0    20005.0
# 3    4228680a-ce97-49c0-8cfd-a13fbd7c0068       0    48347.0
# 4    1f2153bb-0cdb-4ae1-8f1c-df5774b28086       0    20005.0
# ..                                    ...     ...        ...
# 599  3e3150d4-53a3-4b4b-a29d-594fd53aacb6      93     3077.0
# 600  b3c97635-384d-4517-926a-46bfeba1658c      93    20005.0
# 601  a350d989-6f1e-47d5-961c-2ccaecc8f355      94     3509.0
# 602  4a319215-fdb9-4a51-947b-719813a19a96      94     5642.0
# 603  5a830808-27dd-41b7-9df8-8a6a569ba4a7      95     5642.0
#
#                player_name     x     y  end_x  end_y  pass_recipient_id  \
# 0    Michy Batshuayi Tunga  60.0  40.0   52.9   36.0             5642.0
# 1              Axel Witsel  49.9  37.1   32.6   54.2            20005.0
# 2        Toby Alderweireld  32.6  54.2   43.4   52.2            48347.0
# 3             Amadou Onana  43.4  52.2   30.7   56.2            20005.0
# 4        Toby Alderweireld  30.7  56.2   22.8   28.2             3077.0
# ..                     ...   ...   ...    ...    ...                ...
# 599         Jan Vertonghen  56.7  19.2   56.7   48.1            20005.0
# 600      Toby Alderweireld  56.9  47.9   66.6   63.3             3089.0
# 601       Thibaut Courtois  15.2  37.0   29.6   34.8             5642.0
# 602            Axel Witsel  19.7   9.6   27.2   10.0             3077.0
# 603            Axel Witsel  31.3  10.9   45.0   31.4             2954.0
#
#     pass_recipient_name  outcome_id outcome_name  passer  recipient
# 0           Axel Witsel         NaN          NaN      23          6
# 1     Toby Alderweireld         NaN          NaN       6          2
# 2          Amadou Onana         NaN          NaN       2         18
# 3     Toby Alderweireld         NaN          NaN      18          2
# 4        Jan Vertonghen         NaN          NaN       2          5
# ..                  ...         ...          ...     ...        ...
# 599   Toby Alderweireld         NaN          NaN       5          2
# 600     Kevin De Bruyne         NaN          NaN       2          7
# 601         Axel Witsel         NaN          NaN       1          6
# 602      Jan Vertonghen         NaN          NaN       6          5
# 603     Youri Tielemans         NaN          NaN       6          8
#
# [604 rows x 14 columns]

# %%
average_locations= successful.groupby('passer').agg({'x':['mean'],'y':['mean','count']})
average_locations.columns = ['x','y','count']
average_locations
# Out:
#                 x          y  count
# passer
# 1        9.841176  41.720588     34
# 2       45.952128  56.556383     94
# 5       41.221649  27.903093     97
# 6       54.606494  30.980519     77
# 7       71.266667  43.313333     45
# 8       57.462963  38.396296     27
# 9       61.000000  40.100000      1
# 10      72.524000  28.008000     25
# 14      77.300000  32.481818     11
# 15      56.497436  71.241026     39
# 16      68.166667   8.510000     30
# 17      62.180000  14.770000     10
# 18      58.274359  38.964103     39
# 21      50.072308  15.129231     65
# 22      36.566667  64.766667      3
# 23      61.442857  44.071429      7

# %%
pass_between = successful.groupby(['passer','recipient']).id.count().reset_index()
pass_between.rename({'id':'pass_count'},axis='columns',inplace=True)
pass_between
# Out:
#      passer  recipient  pass_count
# 0         1          2           9
# 1         1          5          15
# 2         1          6           2
# 3         1          7           2
# 4         1          8           1
# ..      ...        ...         ...
# 119      22          7           2
# 120      22          8           1
# 121      23          2           1
# 122      23          6           1
# 123      23         10           5
#
# [124 rows x 3 columns]

# %%
pass_between= pd.merge(pass_between, average_locations, on='passer')
pass_between
# Out:
#      passer  recipient  pass_count          x          y  count
# 0         1          2           9   9.841176  41.720588     34
# 1         1          5          15   9.841176  41.720588     34
# 2         1          6           2   9.841176  41.720588     34
# 3         1          7           2   9.841176  41.720588     34
# 4         1          8           1   9.841176  41.720588     34
# ..      ...        ...         ...        ...        ...    ...
# 119      22          7           2  36.566667  64.766667      3
# 120      22          8           1  36.566667  64.766667      3
# 121      23          2           1  61.442857  44.071429      7
# 122      23          6           1  61.442857  44.071429      7
# 123      23         10           5  61.442857  44.071429      7
#
# [124 rows x 6 columns]

# %%
average_locations=average_locations.rename_axis('recipient')
pass_between= pd.merge(pass_between, average_locations, on='recipient',suffixes=['','_end'])
pass_between
# Out:
#      passer  recipient  pass_count          x          y  count      x_end  \
# 0         1          2           9   9.841176  41.720588     34  45.952128
# 1         1          5          15   9.841176  41.720588     34  41.221649
# 2         1          6           2   9.841176  41.720588     34  54.606494
# 3         1          7           2   9.841176  41.720588     34  71.266667
# 4         1          8           1   9.841176  41.720588     34  57.462963
# ..      ...        ...         ...        ...        ...    ...        ...
# 119      22          7           2  36.566667  64.766667      3  71.266667
# 120      22          8           1  36.566667  64.766667      3  57.462963
# 121      23          2           1  61.442857  44.071429      7  45.952128
# 122      23          6           1  61.442857  44.071429      7  54.606494
# 123      23         10           5  61.442857  44.071429      7  72.524000
#
#          y_end  count_end
# 0    56.556383         94
# 1    27.903093         97
# 2    30.980519         77
# 3    43.313333         45
# 4    38.396296         27
# ..         ...        ...
# 119  43.313333         45
# 120  38.396296         27
# 121  56.556383         94
# 122  30.980519         77
# 123  28.008000         25
#
# [124 rows x 9 columns]

# %%
pass_between =pass_between[pass_between['pass_count']>3]
pass_between.drop_duplicates()
pass_between
# Out:
#      passer  recipient  pass_count          x          y  count      x_end  \
# 0         1          2           9   9.841176  41.720588     34  45.952128
# 1         1          5          15   9.841176  41.720588     34  41.221649
# 6         1         21           4   9.841176  41.720588     34  50.072308
# 7         2          1           5  45.952128  56.556383     94   9.841176
# 8         2          5          33  45.952128  56.556383     94  41.221649
# ..      ...        ...         ...        ...        ...    ...        ...
# 110      21          6          12  50.072308  15.129231     65  54.606494
# 113      21         10           5  50.072308  15.129231     65  72.524000
# 115      21         16           9  50.072308  15.129231     65  68.166667
# 117      21         18           8  50.072308  15.129231     65  58.274359
# 123      23         10           5  61.442857  44.071429      7  72.524000
#
#          y_end  count_end
# 0    56.556383         94
# 1    27.903093         97
# 6    15.129231         65
# 7    41.720588         34
# 8    27.903093         97
# ..         ...        ...
# 110  30.980519         77
# 113  28.008000         25
# 115   8.510000         30
# 117  38.964103         39
# 123  28.008000         25
#
# [61 rows x 9 columns]

# %%
pitch = Pitch(pitch_color='green', line_color='#B6BBC4')
# Set the figure size
fig, ax = pitch.draw(figsize=(8, 6), constrained_layout=True, tight_layout=False)

# Set the face color of the figure
fig.set_facecolor('#FFFFFF')

# Draw arrows and nodes
arrows = pitch.arrows(1.2 * pass_between.x, 0.8 * pass_between.y, 1.2 * pass_between.x_end, 0.8 * pass_between.y_end, ax=ax,color='red', alpha=0.4,width=3)
# arrows = pass_between.apply(create_arrow, axis=1)
# for arrow in arrows:
#     ax.add_patch(arrow)
                 
nodes = pitch.scatter(1.2 * average_locations.x, 0.8 * average_locations.y, s=20*average_locations['count'].values, color='white', edgecolors='#a6aab3', linewidth=2, alpha=1, zorder=1, ax=ax)

                 
# Annotate average_locations
for index, row in average_locations.iterrows():
    pitch.annotate(index, xy=(1.2 * row.x, 0.8 * row.y), c='#161A30',fontweight='bold', va='center', ha='center', size=8, ax=ax)

# Add the endnote
ax.text(114, 85, '@samippl1', color='#0E2954', va='bottom', ha='center', fontsize=10)

# Add the title
ax.set_title('Belgium passe in the full match', color='red', va='center', ha='center', fontsize=12,fontweight='bold',pad=20,loc='center')
ax.annotate('2022 FIFA World Cup, Group Stage', xy=(0.5, 1), xytext=(0, 0),
             xycoords='axes fraction', textcoords='offset points',
             fontsize=10, color='#0E2954', va='top', ha='center')


plt.show()
